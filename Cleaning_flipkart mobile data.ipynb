# %%
import pandas as pd

# %%
# Loading the dataset

df = pd.read_csv(r"D:/Data Analytics/PORTFOLIO_PROJECTS/_python_/web_scraping/flipkart_webscraping.csv")
df
# Out:
#      Unnamed: 0                                    Product Name   Prices  \
# 0             0    SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)  ₹26,999
# 1             1   SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)  ₹26,999
# 2             2           SAMSUNG Galaxy S23 5G (Green, 128 GB)  ₹46,999
# 3             3   SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)  ₹46,999
# 4             4        SAMSUNG Galaxy S23 FE (Graphite, 256 GB)  ₹39,999
# ..          ...                                             ...      ...
# 235         235              OnePlus 10R (Sierra Black, 128 GB)  ₹30,498
# 236         236           OnePlus 10R 5G (Sierra Black, 256 GB)  ₹39,999
# 237         237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)  ₹37,999
# 238         238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)  ₹37,999
# 239         239         SAMSUNG A52s 5G (Awesome Black, 128 GB)  ₹38,999
#
#                                            Description  Ratings
# 0    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...      NaN
# 1    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...      NaN
# 2    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...      4.5
# 3    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...      4.5
# 4    8 GB RAM | 256 GB ROM16.26 cm (6.4 inch) Full ...      4.3
# ..                                                 ...      ...
# 235  8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Displ...      4.3
# 236  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...      4.2
# 237  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...      4.2
# 238  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...      4.2
# 239  6 GB RAM | 128 GB ROM16.51 cm (6.5 inch) Displ...      4.1
#
# [240 rows x 5 columns]

# %%
# Deleting the Unnamed column
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#                                        Product Name   Prices  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)  ₹26,999
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)  ₹26,999
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)  ₹46,999
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)  ₹46,999
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)  ₹39,999
# ..                                              ...      ...
# 235              OnePlus 10R (Sierra Black, 128 GB)  ₹30,498
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)  ₹39,999
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)  ₹37,999
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)  ₹37,999
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)  ₹38,999
#
#                                            Description  Ratings
# 0    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...      NaN
# 1    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...      NaN
# 2    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...      4.5
# 3    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...      4.5
# 4    8 GB RAM | 256 GB ROM16.26 cm (6.4 inch) Full ...      4.3
# ..                                                 ...      ...
# 235  8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Displ...      4.3
# 236  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...      4.2
# 237  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...      4.2
# 238  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...      4.2
# 239  6 GB RAM | 128 GB ROM16.51 cm (6.5 inch) Displ...      4.1
#
# [240 rows x 4 columns]

# %%
# Removing special characters from Prices
df['Prices'] = df['Prices'].str.replace('₹', '').str.replace(',', '').fillna(0).astype(int)
df
# Out:
#                                        Product Name  Prices  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)   26999
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)   26999
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)   46999
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)   46999
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)   39999
# ..                                              ...     ...
# 235              OnePlus 10R (Sierra Black, 128 GB)   30498
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)   39999
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)   37999
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)   37999
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)   38999
#
#                                            Description  Ratings
# 0    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...      NaN
# 1    8 GB RAM | 128 GB ROM | Expandable Upto 1 TB17...      NaN
# 2    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...      4.5
# 3    8 GB RAM | 128 GB ROM15.49 cm (6.1 inch) Full ...      4.5
# 4    8 GB RAM | 256 GB ROM16.26 cm (6.4 inch) Full ...      4.3
# ..                                                 ...      ...
# 235  8 GB RAM | 128 GB ROM17.02 cm (6.7 inch) Displ...      4.3
# 236  12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Disp...      4.2
# 237  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...      4.2
# 238  8 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...      4.2
# 239  6 GB RAM | 128 GB ROM16.51 cm (6.5 inch) Displ...      4.1
#
# [240 rows x 4 columns]

# %%
# Normalizing Description field by extracting "RAM","ROM" components
df['Description'] = df['Description'].str.split('|')
df['RAM'] = df['Description'].apply(lambda x: x[0].strip() if len(x) > 0 else '')
df['ROM'] = df['Description'].apply(lambda x: x[1].strip().split('ROM')[0] + 'ROM' if len(x) > 1 else '')

df
# Out:
#                                        Product Name  Prices  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)   26999
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)   26999
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)   46999
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)   46999
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)   39999
# ..                                              ...     ...
# 235              OnePlus 10R (Sierra Black, 128 GB)   30498
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)   39999
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)   37999
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)   37999
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)   38999
#
#                                            Description  Ratings        RAM  \
# 0    [8 GB RAM ,  128 GB ROM ,  Expandable Upto 1 T...      NaN   8 GB RAM
# 1    [8 GB RAM ,  128 GB ROM ,  Expandable Upto 1 T...      NaN   8 GB RAM
# 2    [8 GB RAM ,  128 GB ROM15.49 cm (6.1 inch) Ful...      4.5   8 GB RAM
# 3    [8 GB RAM ,  128 GB ROM15.49 cm (6.1 inch) Ful...      4.5   8 GB RAM
# 4    [8 GB RAM ,  256 GB ROM16.26 cm (6.4 inch) Ful...      4.3   8 GB RAM
# ..                                                 ...      ...        ...
# 235  [8 GB RAM ,  128 GB ROM17.02 cm (6.7 inch) Dis...      4.3   8 GB RAM
# 236  [12 GB RAM ,  256 GB ROM17.02 cm (6.7 inch) Di...      4.2  12 GB RAM
# 237  [8 GB RAM ,  128 GB ROM ,  Expandable Upto 1 T...      4.2   8 GB RAM
# 238  [8 GB RAM ,  128 GB ROM ,  Expandable Upto 1 T...      4.2   8 GB RAM
# 239  [6 GB RAM ,  128 GB ROM16.51 cm (6.5 inch) Dis...      4.1   6 GB RAM
#
#             ROM
# 0    128 GB ROM
# 1    128 GB ROM
# 2    128 GB ROM
# 3    128 GB ROM
# 4    256 GB ROM
# ..          ...
# 235  128 GB ROM
# 236  256 GB ROM
# 237  128 GB ROM
# 238  128 GB ROM
# 239  128 GB ROM
#
# [240 rows x 6 columns]

# %%
# Deleting the original Description column
df = df.drop(columns=['Description'])
df
# Out:
#                                        Product Name  Prices  Ratings  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)   26999      NaN
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)   26999      NaN
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)   46999      4.5
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)   46999      4.5
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)   39999      4.3
# ..                                              ...     ...      ...
# 235              OnePlus 10R (Sierra Black, 128 GB)   30498      4.3
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)   39999      4.2
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)   37999      4.2
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)   37999      4.2
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)   38999      4.1
#
#            RAM         ROM
# 0     8 GB RAM  128 GB ROM
# 1     8 GB RAM  128 GB ROM
# 2     8 GB RAM  128 GB ROM
# 3     8 GB RAM  128 GB ROM
# 4     8 GB RAM  256 GB ROM
# ..         ...         ...
# 235   8 GB RAM  128 GB ROM
# 236  12 GB RAM  256 GB ROM
# 237   8 GB RAM  128 GB ROM
# 238   8 GB RAM  128 GB ROM
# 239   6 GB RAM  128 GB ROM
#
# [240 rows x 5 columns]

# %%
# Handling Missing Values by filling it with "Unknown" or 0
df = df.fillna({'Product Name': 'Unknown', 'Prices': 0, 'Ratings': 0, 'RAM': 'Unknown', 'ROM': 'Unknown'})
df
# Out:
#                                        Product Name  Prices  Ratings  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)   26999      0.0
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)   26999      0.0
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)   46999      4.5
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)   46999      4.5
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)   39999      4.3
# ..                                              ...     ...      ...
# 235              OnePlus 10R (Sierra Black, 128 GB)   30498      4.3
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)   39999      4.2
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)   37999      4.2
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)   37999      4.2
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)   38999      4.1
#
#            RAM         ROM
# 0     8 GB RAM  128 GB ROM
# 1     8 GB RAM  128 GB ROM
# 2     8 GB RAM  128 GB ROM
# 3     8 GB RAM  128 GB ROM
# 4     8 GB RAM  256 GB ROM
# ..         ...         ...
# 235   8 GB RAM  128 GB ROM
# 236  12 GB RAM  256 GB ROM
# 237   8 GB RAM  128 GB ROM
# 238   8 GB RAM  128 GB ROM
# 239   6 GB RAM  128 GB ROM
#
# [240 rows x 5 columns]

# %%
# List of known brands
known_brands = ["SAMSUNG", "OnePlus", "VIVO", "Xiaomi", "Realme", "OPPO", "Apple", "Nokia", "Motorola", "Poco", "Infinix", "Tecno", "Google"]

# Function to extract brand from "Product Name"
def extract_brand(product_name):
    for brand in known_brands:
        if product_name.upper().startswith(brand.upper()):
            return brand
    return 'Unknown'

# Applying the function to the 'Product Name' column to create the 'Brand' column
df['Brand'] = df['Product Name'].apply(extract_brand)
df
# Out:
#                                        Product Name  Prices  Ratings  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)   26999      0.0
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)   26999      0.0
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)   46999      4.5
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)   46999      4.5
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)   39999      4.3
# ..                                              ...     ...      ...
# 235              OnePlus 10R (Sierra Black, 128 GB)   30498      4.3
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)   39999      4.2
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)   37999      4.2
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)   37999      4.2
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)   38999      4.1
#
#            RAM         ROM    Brand
# 0     8 GB RAM  128 GB ROM  SAMSUNG
# 1     8 GB RAM  128 GB ROM  SAMSUNG
# 2     8 GB RAM  128 GB ROM  SAMSUNG
# 3     8 GB RAM  128 GB ROM  SAMSUNG
# 4     8 GB RAM  256 GB ROM  SAMSUNG
# ..         ...         ...      ...
# 235   8 GB RAM  128 GB ROM  OnePlus
# 236  12 GB RAM  256 GB ROM  OnePlus
# 237   8 GB RAM  128 GB ROM  SAMSUNG
# 238   8 GB RAM  128 GB ROM  SAMSUNG
# 239   6 GB RAM  128 GB ROM  SAMSUNG
#
# [240 rows x 6 columns]

# %%
# Removing Duplicates
df = df.drop_duplicates()
df
# Out:
#                                        Product Name  Prices  Ratings  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)   26999      0.0
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)   26999      0.0
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)   46999      4.5
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)   46999      4.5
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)   39999      4.3
# ..                                              ...     ...      ...
# 235              OnePlus 10R (Sierra Black, 128 GB)   30498      4.3
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)   39999      4.2
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)   37999      4.2
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)   37999      4.2
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)   38999      4.1
#
#            RAM         ROM    Brand
# 0     8 GB RAM  128 GB ROM  SAMSUNG
# 1     8 GB RAM  128 GB ROM  SAMSUNG
# 2     8 GB RAM  128 GB ROM  SAMSUNG
# 3     8 GB RAM  128 GB ROM  SAMSUNG
# 4     8 GB RAM  256 GB ROM  SAMSUNG
# ..         ...         ...      ...
# 235   8 GB RAM  128 GB ROM  OnePlus
# 236  12 GB RAM  256 GB ROM  OnePlus
# 237   8 GB RAM  128 GB ROM  SAMSUNG
# 238   8 GB RAM  128 GB ROM  SAMSUNG
# 239   6 GB RAM  128 GB ROM  SAMSUNG
#
# [202 rows x 6 columns]

# %%
# Rearranging the columns
df = df[['Product Name', 'Brand', 'Prices', 'RAM', 'ROM', 'Ratings']]

# %%
# Saving the cleaned DataFrame to a new CSV file
df.to_csv("D:/Data Analytics/PORTFOLIO_PROJECTS/_python_/web_scraping/flipkart_cleaned.csv", index=False)

# %%
# Displaying the cleaned data frame
df
# Out:
#                                        Product Name    Brand  Prices  \
# 0      SAMSUNG Galaxy F55 5G (Raisin Black, 128 GB)  SAMSUNG   26999
# 1     SAMSUNG Galaxy F55 5G (Apricot Crush, 128 GB)  SAMSUNG   26999
# 2             SAMSUNG Galaxy S23 5G (Green, 128 GB)  SAMSUNG   46999
# 3     SAMSUNG Galaxy S23 5G (Phantom Black, 128 GB)  SAMSUNG   46999
# 4          SAMSUNG Galaxy S23 FE (Graphite, 256 GB)  SAMSUNG   39999
# ..                                              ...      ...     ...
# 235              OnePlus 10R (Sierra Black, 128 GB)  OnePlus   30498
# 236           OnePlus 10R 5G (Sierra Black, 256 GB)  OnePlus   39999
# 237  SAMSUNG Galaxy A52s 5G (Awesome Black, 128 GB)  SAMSUNG   37999
# 238  SAMSUNG Galaxy A52s 5G (Awesome White, 128 GB)  SAMSUNG   37999
# 239         SAMSUNG A52s 5G (Awesome Black, 128 GB)  SAMSUNG   38999
#
#            RAM         ROM  Ratings
# 0     8 GB RAM  128 GB ROM      0.0
# 1     8 GB RAM  128 GB ROM      0.0
# 2     8 GB RAM  128 GB ROM      4.5
# 3     8 GB RAM  128 GB ROM      4.5
# 4     8 GB RAM  256 GB ROM      4.3
# ..         ...         ...      ...
# 235   8 GB RAM  128 GB ROM      4.3
# 236  12 GB RAM  256 GB ROM      4.2
# 237   8 GB RAM  128 GB ROM      4.2
# 238   8 GB RAM  128 GB ROM      4.2
# 239   6 GB RAM  128 GB ROM      4.1
#
# [202 rows x 6 columns]
